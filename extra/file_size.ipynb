# %%
import os

# Path to your PDF dataset
pdf_dir = "dataset_single_lora_final.jsonl"

# Count only files (ignore folders)
num_files = len([f for f in os.listdir(pdf_dir) if os.path.isfile(os.path.join(pdf_dir, f))])

print(f"Total number of files in {pdf_dir}: {num_files}")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 7
#       4 pdf_dir = "dataset_single_lora_final.jsonl"
#       6 # Count only files (ignore folders)
# ----> 7 num_files = len([f for f in os.listdir(pdf_dir) if os.path.isfile(os.path.join(pdf_dir, f))])
#       9 print(f"Total number of files in {pdf_dir}: {num_files}")
#
# NotADirectoryError: [Errno 20] Not a directory: 'dataset_single_lora_final.jsonl'

# %%
import pandas as pd

# Path to your LoRA format JSONL file
lora_file = "dataset_single_lora_final.jsonl"

# Load JSONL into a DataFrame
df = pd.read_json(lora_file, lines=True)

# ✅ Print row and column count
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
print(f"Column names: {df.columns.tolist()}")

# Preview first 5 rows
print("\nPreview of data:")
print(df.head())
# Out:
# Total rows: 300803
# Total columns: 4
# Column names: ['instruction', 'input', 'output', 'metadata']
#
# Preview of data:
#                                          instruction  \
# 0  Given the text of an Indian court judgment, pr...
# 1  Given the text of an Indian court judgment, pr...
# 2  Given the text of an Indian court judgment, pr...
# 3  Given the text of an Indian court judgment, pr...
# 4  Given the text of an Indian court judgment, pr...
#
#                                                input    output  \
# 0  Judgment on 18th April, 2008.Bhaskar J.These t...  Rejected
# 1  Beaumont, C.J.This is an appeal from a decisio...  Rejected
# 2  The appellant has filed this appeal assailing ...  Rejected
# 3  The petitioner, Forbes Forbes Campbel and.Comp...  Accepted
# 4  The writ petitioner was allotted plot No.60 fo...  Accepted
#
#                                             metadata
# 0  {'filename': 'Calcutta_High_Court_Appellete_Si...
# ...
